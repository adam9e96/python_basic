# %% [markdown]
# ### 공공 데이터 포탈에서 다운받은 '소상공인시장진흥공단_상가(상권)정보_경북_202312'을 사용.
#
#  1. 필요한 정보만 데이터 프레임으로 변경
#  2. 경산, 표준산업분류명: 커피전문점 지도에 표시

# %%
import pandas as pd
import matplotlib
import folium

# %%
#1. 필요한 데이터 정보만 데이터 프레임으로 변경
df = pd.read_csv('./input/소상공인시장진흥공단_상가(상권)정보_경북_202312.csv')
df.head()
# Out:
#                  상가업소번호     상호명  지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드 상권업종중분류명  \
# 0  MA010120220805431708    솔밭민박  NaN        I1       숙박      I101    일반 숙박
# 1  MA010120220805432237     의성탕  NaN        S2    수리·개인      S208  욕탕·신체관리
# 2  MA010120220805432258   머릿결사랑  NaN        S2    수리·개인      S207    이용·미용
# 3  MA010120220805432850     아지트  NaN        I2       음식      I211       주점
# 4  MA010120220805436067  백석탄골부리  NaN        R1   예술·스포츠      R104   유원지·오락
#
#   상권업종소분류코드      상권업종소분류명 표준산업분류코드  ...                     건물관리번호  건물명  \
# 0    I10103            펜션   I55104  ...  4725042023105670001000001  NaN
# 1    S20801       목욕탕/사우나   S96121  ...  4773025022107490010004046  NaN
# 2    S20701           미용실   S96112  ...  4717012200102240005024992  NaN
# 3    I21104         요리 주점   I56219  ...  4713012400104380004025066  NaN
# 4    R10499  기타 오락관련 서비스업   R91299  ...  4775035040101090000000001  NaN
#
#                       도로명주소   구우편번호  신우편번호  동정보  층정보  호정보          경도  \
# 0   경상북도 상주시 화북면 문장로 1502-9  742871  37102  NaN  NaN  NaN  127.922707
# 1       경상북도 의성군 의성읍 군청길 69  769803  37339  NaN  NaN  NaN  128.701183
# 2         경상북도 안동시 서경지5길 71  760904  36676  NaN    1  NaN  128.715714
# 3           경상북도 경주시 용담로 82  780954  38084  NaN    2  NaN  129.212801
# 4  경상북도 청송군 안덕면 백석탄로 541-21  763862  37449  NaN  NaN  NaN  128.995628
#
#           위도
# 0  36.543640
# 1  36.352030
# 2  36.559903
# 3  35.863751
# 4  36.349543
#
# [5 rows x 39 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 138545 entries, 0 to 138544
# Data columns (total 39 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   상가업소번호     138545 non-null  object
#  1   상호명        138545 non-null  object
#  2   지점명        1691 non-null    object
#  3   상권업종대분류코드  138545 non-null  object
#  4   상권업종대분류명   138545 non-null  object
#  5   상권업종중분류코드  138545 non-null  object
#  6   상권업종중분류명   138545 non-null  object
#  7   상권업종소분류코드  138545 non-null  object
#  8   상권업종소분류명   138545 non-null  object
#  9   표준산업분류코드   138487 non-null  object
#  10  표준산업분류명    138487 non-null  object
#  11  시도코드       138545 non-null  int64
#  12  시도명        138545 non-null  object
#  13  시군구코드      138545 non-null  int64
#  14  시군구명       138545 non-null  object
#  15  행정동코드      138545 non-null  int64
#  16  행정동명       138545 non-null  object
#  17  법정동코드      138545 non-null  int64
#  18  법정동명       138545 non-null  object
#  19  지번코드       138545 non-null  int64
#  20  대지구분코드     138545 non-null  int64
#  21  대지구분명      138545 non-null  object
#  22  지번본번지      138534 non-null  float64
#  23  지번부번지      111220 non-null  float64
#  24  지번주소       138545 non-null  object
#  25  도로명코드      138545 non-null  int64
#  26  도로명        138545 non-null  object
#  27  건물본번지      138545 non-null  int64
#  28  건물부번지      38608 non-null   float64
#  29  건물관리번호     138542 non-null  object
#  30  건물명        22445 non-null   object
#  31  도로명주소      138545 non-null  object
#  32  구우편번호      138545 non-null  int64
#  33  신우편번호      138545 non-null  int64
#  34  동정보        0 non-null       float64
#  35  층정보        41952 non-null   object
#  36  호정보        0 non-null       float64
#  37  경도         138545 non-null  float64
#  38  위도         138545 non-null  float64
# dtypes: float64(7), int64(10), object(22)
# memory usage: 41.2+ MB

# %%
# df2 = df.columns.map(str)
# df2

# %%
df['시군구명'].values
# Out:
# array(['상주시', '의성군', '안동시', ..., '청도군', '포항시 남구', '칠곡군'], dtype=object)

# %%
df2= df[['표준산업분류명', '도로명', '경도' ,'위도','시군구명','상호명']]
df2
# Out:
#                        표준산업분류명                  도로명          경도         위도  \
# 0                          민박업     경상북도 상주시 화북면 문장로  127.922707  36.543640
# 1                          욕탕업     경상북도 의성군 의성읍 군청길  128.701183  36.352030
# 2                       두발 미용업       경상북도 안동시 서경지5길  128.715714  36.559903
# 3                       기타 주점업         경상북도 경주시 용담로  129.212801  35.863751
# 4       그 외 기타 분류 안된 오락관련 서비스업    경상북도 청송군 안덕면 백석탄로  128.995628  36.349543
# ...                        ...                  ...         ...        ...
# 138540               모터사이클 수리업     경상북도 상주시 외남면 석단로  128.089427  36.358164
# 138541              한식 일반 음식점업    경상북도 안동시 풍천면 풍요6길  128.500179  36.576034
# 138542                  고용 알선업     경상북도 청도군 금천면 금천로  128.888500  35.694607
# 138543              한식 일반 음식점업      경상북도 포항시 남구 상공로  129.358611  36.015412
# 138544                통신기기 소매업  경상북도 칠곡군 북삼읍 금오대로1길  128.347027  36.069870
#
#           시군구명            상호명
# 0          상주시           솔밭민박
# 1          의성군            의성탕
# 2          안동시          머릿결사랑
# 3          경주시            아지트
# 4          청송군         백석탄골부리
# ...        ...            ...
# 138540     상주시         현대오토바이
# 138541     안동시  온천골가마솥국밥경북도청점
# 138542     청도군         청도친구인력
# 138543  포항시 남구       도리도리닭도리탕
# 138544     칠곡군          베스트통신
#
# [138545 rows x 6 columns]

# %%
df3 = df2[df2['시군구명'] == '경산시']
df3.head()
# Out:
#                표준산업분류명                  도로명          경도         위도 시군구명  \
# 8          한식 면 요리 전문점         경상북도 경산시 백양로  128.753874  35.813843  경산시
# 10  기타 음ㆍ식료품 위주 종합 소매업         경상북도 경산시 궁당로  128.750477  35.844365  경산시
# 27            서양식 음식점업  경상북도 경산시 진량읍 공단2로7길  128.822719  35.872247  경산시
# 28          조리 반찬류 소매업        경상북도 경산시 어봉지길  128.788316  35.786411  경산시
# 30             자동차 세차업    경상북도 경산시 진량읍 황제1길  128.817967  35.859157  경산시
#
#        상호명
# 8   칼국수한그릇
# 10   영할인마트
# 27   우성돈까스
# 28  피스풀테이블
# 30  오케이세차장

# %%
df4 = df3[df3['표준산업분류명']== '커피 전문점']
df4
# Out:
#        표준산업분류명                  도로명          경도         위도 시군구명         상호명
# 435     커피 전문점     경상북도 경산시 진량읍 다문로  128.817535  35.875275  경산시    아틀리에빈진량점
# 510     커피 전문점      경상북도 경산시 경안로38길  128.737730  35.825841  경산시    더벤티경산중방점
# 538     커피 전문점      경상북도 경산시 백자로20길  128.761142  35.812436  경산시       너와나커피
# 565     커피 전문점         경상북도 경산시 경산로  128.729624  35.818094  경산시       눈꽃이피다
# 931     커피 전문점   경상북도 경산시 하양읍 문화로4길  128.816056  35.912464  경산시         해르트
# ...        ...                  ...         ...        ...  ...         ...
# 136391  커피 전문점  경상북도 경산시 압량읍 압독4로1길  128.764731  35.838254  경산시        짹슨커피
# 136967  커피 전문점     경상북도 경산시 자인면 북사로  128.823483  35.822976  경산시  베러먼데이경산자인점
# 137003  커피 전문점      경상북도 경산시 펜타힐즈2로  128.719311  35.828016  경산시  베러먼데이펜타힐즈점
# 137242  커피 전문점         경상북도 경산시 백천길  128.739408  35.796790  경산시          꼬깜
# 138275  커피 전문점      경상북도 경산시 솔숲길12길  128.758032  35.806534  경산시        르솔커피
#
# [604 rows x 6 columns]

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 604 entries, 435 to 138275
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   표준산업분류명  604 non-null    object
#  1   도로명      604 non-null    object
#  2   경도       604 non-null    float64
#  3   위도       604 non-null    float64
#  4   시군구명     604 non-null    object
#  5   상호명      604 non-null    object
# dtypes: float64(2), object(4)
# memory usage: 33.0+ KB

# %%
import folium.map

gyeongsan_map = folium.Map(location=[35.9542891, 128.833745], zoom_star=13, tiles='Cartodb Positron')
gyeongsan_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_040cf6ad1dd2df9f49b489f5caee68ab {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_040cf6ad1dd2df9f49b489f5caee68ab&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_040cf6ad1dd2df9f49b489f5caee68ab = L.map(
#                 &quot;map_040cf6ad1dd2df9f49b489f5caee68ab&quot;,
#                 {
#                     center: [35.9542891, 128.833745],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     zoomStar: 13,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a283c031d4deef1cdfdddbaada37cd7b = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_a283c031d4deef1cdfdddbaada37cd7b.addTo(map_040cf6ad1dd2df9f49b489f5caee68ab);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# popup : 마우스 클릭시 나옴 : tooltip : 마우스 호버 시 나옴
for name, lat, lng in zip(df4['상호명'], df4['위도'], df4['경도']):
    tooltip= folium.Tooltip(name, permanent=True)
    folium.Marker(location=[lat,lng],tooltip=tooltip).add_to(gyeongsan_map)
gyeongsan_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_040cf6ad1dd2df9f49b489f5caee68ab {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_040cf6ad1dd2df9f49b489f5caee68ab&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_040cf6ad1dd2df9f49b489f5caee68ab = L.map(
#                 &quot;map_040cf6ad1dd2df9f49b489f5caee68ab&quot;,
#                 {
#                     center: [35.9542891, 128.833745],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     zoomStar: 13,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a283c031d4deef1cdfdddbaada37cd7b = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_a283c031d4deef1cdfdddbaada37cd7b.addTo(map_040cf6ad1dd2df9f49b489f5caee68ab);
#
#
#             tile_layer_a283c031d4deef1cdfdddbaada37cd7b.addTo(map_040cf6ad1dd2df9f49b489f5caee68ab);
#
#
#             var marker_735f4ec3ac3db15c4ba9535b8fef0be1 = L.marker(
#                 [35.875275100868, 128.817534579273],
#                 {}
#             ).addTo(map_040cf6ad1dd2df9f49b489f5caee68ab);
#
#
#             marker_735f4ec3ac3db15c4ba9535b8fef0be1.bindTooltip(
#                 `&lt;div&gt;
#                      아틀리에빈진량점
#                  &lt;/div&gt;`,
#                 {&quot;permanent&quot;: true, &quot;sticky&quot;: true}
#             );
#
#
#             var marker_82f2a49df16eb058b82d8306c119cfe8 = L.marker(
#                 [35.825840733898, 128.737729633965],
#                 {}
#             ).addTo(map_040cf6ad1dd2df9f49b489f5caee68ab);
#
#
#             marker_82f2a49df16eb058b82d8306c119cfe8.bindTooltip(
#                 `&lt;div&gt;
#                      더벤티경산중방점
#                  &lt;/div&gt;`,
#                 {&quot;permanent&quot;: true, &quot;sticky&quot;: true}
#             );
#
#
#             var marker_0703180731031f7433051f2fecbd8bbd = L.marker(
#                 [35.8124363446034, 128.761142011233],
#                 {}
#             ).addTo(map_040cf6ad1dd2df9f49b489f5caee68ab);
#
#
#             marker_0703180731031f7433051f2fecbd8bbd.bindTooltip(
#                 `&lt;div&gt;
#                      너와나커피
#                  &lt;/div&gt;`,
#                 {&quot;permanent&quot;: true, &quot;sticky&quot;: true}
#             );
#
#
#             var marker_75d1cf8251212210013b83433cbd6002 = L.marker(
#                 [35.8180937806526, 128.729623804169],
#                 {}
#             ).addTo(map_040cf6ad1dd2df9f49b489f5caee68ab);
#
#
#             marker_75d1cf8251212210013b83433cbd6002.bindTooltip(
#                 `&lt;div&gt;
#                      눈꽃이피다
#                  &lt;/div&gt;`,
#                 {&quot;permanent&quot;: true, &quot;sticky&quot;: true}
#             );
#
#
#             var marker_72efc22a96d250915218e2d841fe3c60 = L.marker(
#                 [35.9124639840638, 128.816055668915],
#                 {}
#             ).addTo(map_040cf6ad1dd2df9f49b489f5caee68ab);
#
#
#             marker_72efc22a96d250915218e2d841fe3c60.bindTooltip(
#                 `&lt;div&gt;
#                      해르트
#                  &lt;/div&gt;`,
#                 {&quot;permanent&quot;: true, &quot;sticky&quot;: true}
#             );
#
#
#             var marker_2f4923158e2bad5c053e0a7bfd15c88e = L.marker(
#                 [35.8066085869178, 128.74178953523],
#                 {}
#             ).addTo(map_040cf6ad1dd2df9f49b489f5caee68ab);
#
#
#             marker_2f4923158e2bad5c053e0a7bfd15c88e.bindTooltip(
#                 `&lt;div&gt;
#                      아틀리에빈백천유스파점
#                  &lt;/div&gt;`,
#                 {&quot;permanent&quot;: true, &quot;sticky&quot;: true}
#             );
#
#
#             var marker_b209d79ec4cf04e267422cf032d7cbf6 = L.marker(
#                 [35.84149099414, 128.761751565446],
#                 {}
#             ).addTo(map_040cf6ad1dd2df9f49b489f5caee68ab);
#
#
#             marker_b209d79ec4cf04e267422cf032d7cbf6.bindTooltip(
#                 `&lt;div&gt;
#                      별다방미스리
#                  &lt;/div&gt;`,
#                 {&quot;permanent&quot;: true, &quot;sticky&quot;: true}
#             );
#
#
#             var marker_410ec6345e21b72353a3f0b63c142383 = L.marker(
#                 [35.8376791838383, 128.754487050013],
#                 {}
#             ).addTo(map_040cf6ad1dd2df9f49b489f5caee68ab);
#
#
#             marker_410ec6345e21b72353a3f0b63c142383.bindTooltip(
#                 `&lt;div&gt;
#                      모리커피
#                  &lt;/div&gt;`,
#                 {&quot;permanent&quot;: true, &quot;sticky&quot;: true}
#             );
#
#
#             var marker_613f946978b57f5910857cc0f1cdae32 = L.marker(
#                 [35.8248242235838, 128.724063224585],
#                 {}

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 604 entries, 435 to 138275
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   표준산업분류명  604 non-null    object
#  1   도로명      604 non-null    object
#  2   경도       604 non-null    float64
#  3   위도       604 non-null    float64
#  4   시군구명     604 non-null    object
#  5   상호명      604 non-null    object
# dtypes: float64(2), object(4)
# memory usage: 33.0+ KB

# %%
gyeongsan_map.save('./output/gyeongsan_map.html')
