# %% [markdown]
# # 03. 지도에 마커 표시하기
#
# - 서울 시내 주요 대학교의 위치 데이터를 데이터 프레임으로 반환하고, folium 지도에 위치를 표시.

# %%
import pandas as pd
import folium

# %%
# 해각교 리스트를 데이터프레임 변환
df = pd.read_excel('./input/서울지역 대학교 위치.xlsx')
df.head()  # df는 데이터 프레임 객체임.
# Out:
#            name         위도          경도
# 0  KAIST 서울캠퍼스   37.592573  127.046737
# 1         KC대학교  37.548345  126.854797
# 2  가톨릭대학교(성신교정)  37.585922  127.004328
# 3  가톨릭대학교(성의교정)  37.499623  127.006065
# 4      감리교신학대학교  37.567645  126.961610

# %%
df.columns
# Out:
# Index(['name', '위도', '경도'], dtype='object')

# %%
df.values
# Out:
# array([['KAIST 서울캠퍼스 ', 37.592573, 127.046737],
#        ['KC대학교', 37.5483449, 126.8547974],
#        ['가톨릭대학교(성신교정)', 37.5859218, 127.0043275],
#        ['가톨릭대학교(성의교정)', 37.4996227, 127.0060653],
#        ['감리교신학대학교', 37.5676455, 126.96161],
#        ['건국대학교', 37.5407625, 127.0793428],
#        ['경기대학교 서울캠퍼스 ', 37.30048499999999, 127.035833],
#        ['경희대학교 서울캠퍼스 ', 37.5961951, 127.052544],
#        ['고려대학교', 33.8477818, -117.9777482],
#        ['광운대학교', 37.6194965, 127.0596958],
#        ['국민대학교', 37.6096409, 126.997697],
#        ['덕성여자대학교', 37.6511988, 127.0161604],
#        ['동국대학교', 37.5574771, 127.0020518],
#        ['동덕여자대학교', 37.6063202, 127.041808],
#        ['명지대학교 서울캠퍼스 ', 37.5802046, 126.9234451],
#        ['삼육대학교', 37.6429515, 127.1054757],
#        ['상명대학교\xa0서울캠퍼스 ', 37.602638, 126.955252],
#        ['서강대학교', 37.5509442, 126.9410023],
#        ['서경대학교', 37.615095, 127.0131113],
#        ['서울과학기술대학교', 37.6316684, 127.0774813],
#        ['서울교육대학교', 37.4899615, 127.0164124],
#        ['서울기독대학교', 37.6009228, 126.9123818],
#        ['서울대학교', 37.459882, 126.9519053],
#        ['서울시립대학교', 37.5838657, 127.0587771],
#        ['서울여자대학교', 37.6281126, 127.0904568],
#        ['서울한영대학교', 37.4965411, 126.8512616],
#        ['성공회대학교', 37.4872325, 126.8253202],
#        ['성균관대학교 서울캠퍼스 \xa0', 37.588227, 126.993606],
#        ['성신여자대학교', 37.5913103, 127.0221312],
#        ['세종대학교', 37.5502596, 127.073139],
#        ['숙명여자대학교', 37.5463644, 126.9648311],
#        ['숭실대학교', 37.4963111, 126.9574596],
#        ['연세대학교', 37.565784, 126.938572],
#        ['육군사관학교', 37.6238188, 127.0988783],
#        ['이화여자대학교', 37.5643079, 126.9501786],
#        ['장로회신학대학교', 37.5505112, 127.1034577],
#        ['중앙대학교 서울캠퍼스 ', 37.5050881, 126.9571012],
#        ['총신대학교', 37.4886232, 126.9668169],
#        ['추계예술대학교', 37.5624515, 126.9534165],
#        ['한국방송통신대학교', 37.5786127, 127.0032905],
#        ['한국성서대학교', 37.6487485, 127.0643199],
#        ['한국예술종합학교', 37.6049973, 127.0567397],
#        ['한국외국어대학교', 37.597319, 127.057843],
#        ['한국체육대학교', 37.5196266, 127.1309837],
#        ['한성대학교', 37.5817849, 127.010369],
#        ['한양대학교', 37.5572321, 127.0453219],
#        ['홍익대학교', 37.5514642, 126.9250106]], dtype=object)

# %%
# 서울 지도 만들기
seoul_map = folium.Map(location=[37.55, 126.98], zoom_start=12)
seoul_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2ff3d363316e7b64f11ef2c196a8374f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2ff3d363316e7b64f11ef2c196a8374f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2ff3d363316e7b64f11ef2c196a8374f = L.map(
#                 &quot;map_2ff3d363316e7b64f11ef2c196a8374f&quot;,
#                 {
#                     center: [37.55, 126.98],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7c4d2992ac666e5ffbe5b15e85951d86 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_7c4d2992ac666e5ffbe5b15e85951d86.addTo(map_2ff3d363316e7b64f11ef2c196a8374f);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# 대학교 위치 정보를 Marker 로 표시
for name, lat, lng in zip(df['name'], df['위도'], df['경도']):
    # folium.Marker([lat,lng],popup=name).add_to(seoul_map)
    folium.Marker([lat, lng], popup=name).add_to(seoul_map)
    # 위도, 경도
# folium.Maker(위도,경도, popup=None).add_to(지도_map객체)
seoul_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2ff3d363316e7b64f11ef2c196a8374f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2ff3d363316e7b64f11ef2c196a8374f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2ff3d363316e7b64f11ef2c196a8374f = L.map(
#                 &quot;map_2ff3d363316e7b64f11ef2c196a8374f&quot;,
#                 {
#                     center: [37.55, 126.98],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7c4d2992ac666e5ffbe5b15e85951d86 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_7c4d2992ac666e5ffbe5b15e85951d86.addTo(map_2ff3d363316e7b64f11ef2c196a8374f);
#
#
#             tile_layer_7c4d2992ac666e5ffbe5b15e85951d86.addTo(map_2ff3d363316e7b64f11ef2c196a8374f);
#
#
#             var marker_3cbfa250a2564fe57af34710041de4bc = L.marker(
#                 [37.592573, 127.046737],
#                 {}
#             ).addTo(map_2ff3d363316e7b64f11ef2c196a8374f);
#
#
#         var popup_909cc3360d8d5443ee6148feb09d6ae9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ac211b86fcaf6e8696d45e76dc628e49 = $(`&lt;div id=&quot;html_ac211b86fcaf6e8696d45e76dc628e49&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;KAIST 서울캠퍼스 &lt;/div&gt;`)[0];
#                 popup_909cc3360d8d5443ee6148feb09d6ae9.setContent(html_ac211b86fcaf6e8696d45e76dc628e49);
#
#
#
#         marker_3cbfa250a2564fe57af34710041de4bc.bindPopup(popup_909cc3360d8d5443ee6148feb09d6ae9)
#         ;
#
#
#
#
#             var marker_d97f3dfd457801834b660c658aace817 = L.marker(
#                 [37.5483449, 126.8547974],
#                 {}
#             ).addTo(map_2ff3d363316e7b64f11ef2c196a8374f);
#
#
#         var popup_4baf7337af992813e22d52de7944af7b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7c8fb08576908a3a40a6271992dc6b0c = $(`&lt;div id=&quot;html_7c8fb08576908a3a40a6271992dc6b0c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;KC대학교&lt;/div&gt;`)[0];
#                 popup_4baf7337af992813e22d52de7944af7b.setContent(html_7c8fb08576908a3a40a6271992dc6b0c);
#
#
#
#         marker_d97f3dfd457801834b660c658aace817.bindPopup(popup_4baf7337af992813e22d52de7944af7b)
#         ;
#
#
#
#
#             var marker_16be71450d41c78b6762599bed02ec3b = L.marker(
#                 [37.5859218, 127.0043275],
#                 {}
#             ).addTo(map_2ff3d363316e7b64f11ef2c196a8374f);
#
#
#         var popup_1519461190cd641e232ebc62ff88d95a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e6ee271be25a297fceead2421c60bf57 = $(`&lt;div id=&quot;html_e6ee271be25a297fceead2421c60bf57&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;가톨릭대학교(성신교정)&lt;/div&gt;`)[0];
#                 popup_1519461190cd641e232ebc62ff88d95a.setContent(html_e6ee271be25a297fceead2421c60bf57);
#
#
#
#         marker_16be71450d41c78b6762599bed02ec3b.bindPopup(popup_1519461190cd641e232ebc62ff88d95a)
#         ;
#
#
#
#
#             var marker_8e379dcf833a3fbdd62ae8d94d4ef2e7 = L.marker(
#                 [37.4996227, 127.0060653],
#                 {}
#             ).addTo(map_2ff3d363316e7b64f11ef2c196a8374f);
#
#
#         var popup_1ccb80d40b5f641474b47311bb1a4007 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_eee00e6f3113f24997c3988fe460c091 = $(`&lt;div id=&quot;html_eee00e6f3113f24997c3988fe460c091&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;가톨릭대학교(성의교정)&lt;/div&gt;`)[0];
#                 popup_1ccb80d40b5f641474b47311bb1a4007.setContent(html_eee00e6f3113f24997c3988fe460c091);
#
#
#
#         marker_8e379dcf833a3fbdd62ae8d94d4ef2e7.bindPopup(popup_1ccb80d40b5f641474b47311bb1a4007)
#         ;
#
#
#
#
#             var marker_d3a896732faaf6bd0a54785d01a657ce = L.marker(
#                 [37.5676455, 126.96161],
#                 {}
#             ).addTo(map_2ff3d363316e7b64f11ef2c196a8374f);
#
#
#         var popup_66240e90a7209ba25bbed6c4a0033f05 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_186cac76dcdce33aec6d67a63c3fd3f5 = $(`&lt;div id=&quot;html_186cac76dcdce33aec6d67a63c3fd3f5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;감리교신학대학교&lt;/div&gt;`)[0];
#                 popup_66240e90a7209ba25bbed6c4a0033f05.setContent(html_186cac76dcdce33aec6d67a63c3fd3f5);
#
#
#
#         marker_d3a896732faaf6bd0a54785d01a657ce.bindPopup(popup_66240e90a7209ba25bbed6c4a0033f05)
#         ;
#
#
#
#
#             var marker_31736efcd2bf5746b9ce657520a2f3a3 = L.marker(
#                 [37.5

# %%
print(type(folium.Map(location=[37.55, 126.98])))
# Out:
# <class 'folium.folium.Map'>

# %%
# 지도를 html 파일로 저장

seoul_map.save('./output/seoul2.html')
