# %% [markdown]
# ## 03. 지도에 마커 표시하기
#
# - 서울 시내 주요 대학교의 위치 데이터를 데이터 프레임으로 반환하고, folium 지도에 위치를 표시.

# %%
import pandas as pd
import folium

# %%
# 해각교 리스트를 데이터프레임 변환
df = pd.read_excel('./input/서울지역 대학교 위치.xlsx')
df.head()   # df는 데이터 프레임 객체임.
# Out:
#            name         위도          경도
# 0  KAIST 서울캠퍼스   37.592573  127.046737
# 1         KC대학교  37.548345  126.854797
# 2  가톨릭대학교(성신교정)  37.585922  127.004328
# 3  가톨릭대학교(성의교정)  37.499623  127.006065
# 4      감리교신학대학교  37.567645  126.961610

# %%
df.columns
# Out:
# Index(['name', '위도', '경도'], dtype='object')

# %%
# 서울 지도 만들기
seoul_map = folium.Map(location=[37.55,126.98], zoom_start=12)
seoul_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_639c54ccad9a7c30f5f094073b97dba6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_639c54ccad9a7c30f5f094073b97dba6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_639c54ccad9a7c30f5f094073b97dba6 = L.map(
#                 &quot;map_639c54ccad9a7c30f5f094073b97dba6&quot;,
#                 {
#                     center: [37.55, 126.98],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d0d302c832c016fc5294dbeb05d401ae = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_d0d302c832c016fc5294dbeb05d401ae.addTo(map_639c54ccad9a7c30f5f094073b97dba6);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# 대학교 위치 정보를 Marker 로 표시
for name, lat, lng in zip(df['name'],df['위도'],df['경도']):
    # folium.Marker([lat,lng],popup=name).add_to(seoul_map)
    folium.Marker([lat, lng], popup=name).add_to(seoul_map)
    # 위도, 경도
# folium.Maker(위도,경도, popup=None).add_to(지도_map객체)
seoul_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_639c54ccad9a7c30f5f094073b97dba6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_639c54ccad9a7c30f5f094073b97dba6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_639c54ccad9a7c30f5f094073b97dba6 = L.map(
#                 &quot;map_639c54ccad9a7c30f5f094073b97dba6&quot;,
#                 {
#                     center: [37.55, 126.98],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d0d302c832c016fc5294dbeb05d401ae = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_d0d302c832c016fc5294dbeb05d401ae.addTo(map_639c54ccad9a7c30f5f094073b97dba6);
#
#
#             tile_layer_d0d302c832c016fc5294dbeb05d401ae.addTo(map_639c54ccad9a7c30f5f094073b97dba6);
#
#
#             var marker_a237b0dd58aab384681920491170889d = L.marker(
#                 [37.592573, 127.046737],
#                 {}
#             ).addTo(map_639c54ccad9a7c30f5f094073b97dba6);
#
#
#         var popup_6017a26336bfc46b0ad2d125f70d769a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c7751422bb084d387d649954cc8a3cb2 = $(`&lt;div id=&quot;html_c7751422bb084d387d649954cc8a3cb2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;KAIST 서울캠퍼스 &lt;/div&gt;`)[0];
#                 popup_6017a26336bfc46b0ad2d125f70d769a.setContent(html_c7751422bb084d387d649954cc8a3cb2);
#
#
#
#         marker_a237b0dd58aab384681920491170889d.bindPopup(popup_6017a26336bfc46b0ad2d125f70d769a)
#         ;
#
#
#
#
#             var marker_b576fd99bb014139fdf18cfe48ddc8e5 = L.marker(
#                 [37.5483449, 126.8547974],
#                 {}
#             ).addTo(map_639c54ccad9a7c30f5f094073b97dba6);
#
#
#         var popup_21f319878d700aec2aa3db4e473e0371 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8bbb88191efd97522c75dfc359c50d09 = $(`&lt;div id=&quot;html_8bbb88191efd97522c75dfc359c50d09&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;KC대학교&lt;/div&gt;`)[0];
#                 popup_21f319878d700aec2aa3db4e473e0371.setContent(html_8bbb88191efd97522c75dfc359c50d09);
#
#
#
#         marker_b576fd99bb014139fdf18cfe48ddc8e5.bindPopup(popup_21f319878d700aec2aa3db4e473e0371)
#         ;
#
#
#
#
#             var marker_8b9bd778a5b58a9fdceda9306f343d87 = L.marker(
#                 [37.5859218, 127.0043275],
#                 {}
#             ).addTo(map_639c54ccad9a7c30f5f094073b97dba6);
#
#
#         var popup_ea61b3b2a5084d4fa8a65745b8d66760 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_987bc490795c211204eee76f28689706 = $(`&lt;div id=&quot;html_987bc490795c211204eee76f28689706&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;가톨릭대학교(성신교정)&lt;/div&gt;`)[0];
#                 popup_ea61b3b2a5084d4fa8a65745b8d66760.setContent(html_987bc490795c211204eee76f28689706);
#
#
#
#         marker_8b9bd778a5b58a9fdceda9306f343d87.bindPopup(popup_ea61b3b2a5084d4fa8a65745b8d66760)
#         ;
#
#
#
#
#             var marker_5339c35e9bc9174f8202911b3a3ffb5e = L.marker(
#                 [37.4996227, 127.0060653],
#                 {}
#             ).addTo(map_639c54ccad9a7c30f5f094073b97dba6);
#
#
#         var popup_37b60d81f216891c84829cf8da24a52d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6a2edf440235cb85998d3759e6b48741 = $(`&lt;div id=&quot;html_6a2edf440235cb85998d3759e6b48741&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;가톨릭대학교(성의교정)&lt;/div&gt;`)[0];
#                 popup_37b60d81f216891c84829cf8da24a52d.setContent(html_6a2edf440235cb85998d3759e6b48741);
#
#
#
#         marker_5339c35e9bc9174f8202911b3a3ffb5e.bindPopup(popup_37b60d81f216891c84829cf8da24a52d)
#         ;
#
#
#
#
#             var marker_6a497c2a2bc234e6179afc8eb7af4899 = L.marker(
#                 [37.5676455, 126.96161],
#                 {}
#             ).addTo(map_639c54ccad9a7c30f5f094073b97dba6);
#
#
#         var popup_1b9b65dcaf566f0e97f843a67687d138 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7d7af6c3fda89d67a39693e743cbe899 = $(`&lt;div id=&quot;html_7d7af6c3fda89d67a39693e743cbe899&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;감리교신학대학교&lt;/div&gt;`)[0];
#                 popup_1b9b65dcaf566f0e97f843a67687d138.setContent(html_7d7af6c3fda89d67a39693e743cbe899);
#
#
#
#         marker_6a497c2a2bc234e6179afc8eb7af4899.bindPopup(popup_1b9b65dcaf566f0e97f843a67687d138)
#         ;
#
#
#
#
#             var marker_d2ad8c87a8cdfdee96c8b0ee55d01e29 = L.marker(
#                 [37.5

# %%
# 지도를 html 파일로 저장

seoul_map.save('./output/seoul2.html')
