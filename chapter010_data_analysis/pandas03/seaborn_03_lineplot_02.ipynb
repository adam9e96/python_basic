# %%
# 3. 북대구 영업소의 2023년 12월 일자 별 총 교통량의 변화를 선그래프로 나타내시오.

# %%
# 패키지 임포트
import matplotlib
import pandas as pd  # pandas(판다스) 패키지 임포트
import matplotlib.pyplot as plt  # Matplotlib(맷플롯립) 패키지의 pyplot 모듈을 plt로 임포트
import seaborn as sns  # Seaborn(씨본) 패키지 임포트
import warnings

matplotlib.rcParams['font.family'] = 'sans-serif'  # Windows
matplotlib.rcParams['axes.unicode_minus'] = False  # 한글 폰트 사용 시, 마이너스 기호가 깨지는 현상 방지

# 경고창 무시
warnings.filterwarnings('ignore')

# %%
tcs = pd.read_csv('./input/TCS_B3_04_03_238959.csv', encoding='cp949')
tcs.head()
# Out:
#          집계일자  영업소코드 영업소명  입출구구분코드 입출구명  TCS하이패스구분코드 TCS하이패스명  고속도로운영기관구분코드  \
# 0  2023-10-01    203   가산        0   입구            1      TCS             0
# 1  2023-10-01    203   가산        0   입구            2  hi-pass             0
# 2  2023-10-01    203   가산        1   출구            1      TCS             0
# 3  2023-10-01    203   가산        1   출구            2  hi-pass             0
# 4  2023-10-01    274   가조        0   입구            1      TCS             0
#
#   고속도로운영기관명  영업형태구분코드 영업형태명  1종교통량  2종교통량  3종교통량  4종교통량  5종교통량  6종교통량   총교통량
# 0    한국도로공사         0   폐쇄식   1045      2      9      2      2      4   1064
# 1    한국도로공사         0   폐쇄식  12150     50     59     44     32    355  12690
# 2    한국도로공사         0   폐쇄식    889      2      7      5      4    127   1034
# 3    한국도로공사         0   폐쇄식   8670     56     31     21     18    250   9046
# 4    한국도로공사         0   폐쇄식    292      0      0      1      0      3    296

# %%
sns.lineplot(data=tcs, x='집계일자', y='총교통량')
plt.show()

# %%
tcs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21528 entries, 0 to 21527
# Data columns (total 18 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   집계일자          21528 non-null  object
#  1   영업소코드         21528 non-null  int64
#  2   영업소명          21528 non-null  object
#  3   입출구구분코드       21528 non-null  int64
#  4   입출구명          21528 non-null  object
#  5   TCS하이패스구분코드   21528 non-null  int64
#  6   TCS하이패스명      21528 non-null  object
#  7   고속도로운영기관구분코드  21528 non-null  int64
#  8   고속도로운영기관명     21528 non-null  object
#  9   영업형태구분코드      21528 non-null  int64
#  10  영업형태명         21528 non-null  object
#  11  1종교통량         21528 non-null  int64
#  12  2종교통량         21528 non-null  int64
#  13  3종교통량         21528 non-null  int64
#  14  4종교통량         21528 non-null  int64
#  15  5종교통량         21528 non-null  int64
#  16  6종교통량         21528 non-null  int64
#  17  총교통량          21528 non-null  int64
# ...

# %%
# 영업소명을 북대구만 포함 하도록 설정
df1 = tcs[tcs['영업소명'] == '북대구']
df1
# Out:
#              집계일자  영업소코드 영업소명  입출구구분코드 입출구명  TCS하이패스구분코드 TCS하이패스명  \
# 110    2023-10-01    129  북대구        0   입구            1      TCS
# 111    2023-10-01    129  북대구        0   입구            2  hi-pass
# 112    2023-10-01    129  북대구        1   출구            1      TCS
# 113    2023-10-01    129  북대구        1   출구            2  hi-pass
# 344    2023-10-02    129  북대구        0   입구            1      TCS
# ...           ...    ...  ...      ...  ...          ...      ...
# 21173  2023-12-30    129  북대구        1   출구            2  hi-pass
# 21404  2023-12-31    129  북대구        0   입구            1      TCS
# 21405  2023-12-31    129  북대구        0   입구            2  hi-pass
# 21406  2023-12-31    129  북대구        1   출구            1      TCS
# 21407  2023-12-31    129  북대구        1   출구            2  hi-pass
#
#        고속도로운영기관구분코드 고속도로운영기관명  영업형태구분코드 영업형태명  1종교통량  2종교통량  3종교통량  4종교통량  \
# 110               0    한국도로공사         0   폐쇄식   3109      5     17     11
# ...

# %%
# date2 변수를 새로 만드는데 집계일자를 이용. 타입은 datetime
df1['date2'] = pd.to_datetime(df1['집계일자'])
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 368 entries, 110 to 21407
# Data columns (total 19 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   집계일자          368 non-null    object
#  1   영업소코드         368 non-null    int64
#  2   영업소명          368 non-null    object
#  3   입출구구분코드       368 non-null    int64
#  4   입출구명          368 non-null    object
#  5   TCS하이패스구분코드   368 non-null    int64
#  6   TCS하이패스명      368 non-null    object
#  7   고속도로운영기관구분코드  368 non-null    int64
#  8   고속도로운영기관명     368 non-null    object
#  9   영업형태구분코드      368 non-null    int64
#  10  영업형태명         368 non-null    object
#  11  1종교통량         368 non-null    int64
#  12  2종교통량         368 non-null    int64
#  13  3종교통량         368 non-null    int64
#  14  4종교통량         368 non-null    int64
#  15  5종교통량         368 non-null    int64
#  16  6종교통량         368 non-null    int64
#  17  총교통량          368 non-null    int64
# ...

# %%
df1[['집계일자', 'date2']].head()  # 집계일자와 date2 조회
# Out:
#            집계일자      date2
# 110  2023-10-01 2023-10-01
# 111  2023-10-01 2023-10-01
# 112  2023-10-01 2023-10-01
# 113  2023-10-01 2023-10-01
# 344  2023-10-02 2023-10-02

# %%
# 2023년 12월 일자 별 총 교통량만 가져오기
# case1
df2 = df1[(df1['date2'] >= '2023-12-01') & (df1['date2'] <= '2023-12-31')]

df2.head()
# df2.tail()

# case2
# df2 = df1[df1['집계일자'].astype(str).str.contains('2023-12')]
# df2.head()  # 북대구 12월자 데이터
# Out:
#              집계일자  영업소코드 영업소명  입출구구분코드 입출구명  TCS하이패스구분코드 TCS하이패스명  \
# 14384  2023-12-01    129  북대구        0   입구            1      TCS
# 14385  2023-12-01    129  북대구        0   입구            2  hi-pass
# 14386  2023-12-01    129  북대구        1   출구            1      TCS
# 14387  2023-12-01    129  북대구        1   출구            2  hi-pass
# 14618  2023-12-02    129  북대구        0   입구            1      TCS
#
#        고속도로운영기관구분코드 고속도로운영기관명  영업형태구분코드 영업형태명  1종교통량  2종교통량  3종교통량  4종교통량  \
# 14384             0    한국도로공사         0   폐쇄식   2717     88    219    115
# 14385             0    한국도로공사         0   폐쇄식  27662    774    639    362
# 14386             0    한국도로공사         0   폐쇄식   3022    102    226    131
# 14387             0    한국도로공사         0   폐쇄식  29767    923    729    444
# 14618             0    한국도로공사         0   폐쇄식   2309     35     85     52
#
#        5종교통량  6종교통량   총교통량      date2
# 14384     32     54   3225 2023-12-01
# 14385    574   1130  31141 2023-12-01
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 124 entries, 14384 to 21407
# Data columns (total 19 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   집계일자          124 non-null    object
#  1   영업소코드         124 non-null    int64
#  2   영업소명          124 non-null    object
#  3   입출구구분코드       124 non-null    int64
#  4   입출구명          124 non-null    object
#  5   TCS하이패스구분코드   124 non-null    int64
#  6   TCS하이패스명      124 non-null    object
#  7   고속도로운영기관구분코드  124 non-null    int64
#  8   고속도로운영기관명     124 non-null    object
#  9   영업형태구분코드      124 non-null    int64
#  10  영업형태명         124 non-null    object
#  11  1종교통량         124 non-null    int64
#  12  2종교통량         124 non-null    int64
#  13  3종교통량         124 non-null    int64
#  14  4종교통량         124 non-null    int64
#  15  5종교통량         124 non-null    int64
#  16  6종교통량         124 non-null    int64
#  17  총교통량          124 non-null    int64
# ...

# %%
df4 = df2.groupby('집계일자', as_index=False).agg(n=('총교통량', 'sum'))
df4
# Out:
#           집계일자      n
# 0   2023-12-01  71976
# 1   2023-12-02  70054
# 2   2023-12-03  61797
# 3   2023-12-04  67023
# 4   2023-12-05  66833
# 5   2023-12-06  65686
# 6   2023-12-07  66767
# 7   2023-12-08  72565
# 8   2023-12-09  73152
# 9   2023-12-10  59379
# 10  2023-12-11  60866
# 11  2023-12-12  64916
# 12  2023-12-13  67510
# 13  2023-12-14  65455
# 14  2023-12-15  65435
# 15  2023-12-16  67876
# 16  2023-12-17  53186
# 17  2023-12-18  65690
# 18  2023-12-19  65322
# 19  2023-12-20  65109
# 20  2023-12-21  65507
# 21  2023-12-22  70512
# 22  2023-12-23  66987
# 23  2023-12-24  54654
# 24  2023-12-25  52784
# 25  2023-12-26  66810
# 26  2023-12-27  66290
# 27  2023-12-28  66424
# 28  2023-12-29  70057
# 29  2023-12-30  62874
# 30  2023-12-31  50627

# %%
plt.figure(figsize=(16, 10))
sns.lineplot(data=df4, x='집계일자', y='n')
plt.show()
