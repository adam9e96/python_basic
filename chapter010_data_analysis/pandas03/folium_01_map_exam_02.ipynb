# %% [markdown]
# ### 공공 데이터 포탈에서 다운받은 '소상공인시장진흥공단_상가(상권)정보_경북_202312'을 사용.
#
#  1. 필요한 정보만 데이터 프레임으로 변경
#  2. 경산, 표준산업분류명: 커피전문점 지도에 표시

# %%
import pandas as pd
import matplotlib
import folium

# %%
#1. 필요한 데이터 정보만 데이터 프레임으로 변경
df = pd.read_csv('./input/소상공인시장진흥공단_상가(상권)정보_경북_202312.csv')
df.head()
# Out:
#                  상가업소번호     상호명  지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드 상권업종중분류명  \
# 0  MA010120220805431708    솔밭민박  NaN        I1       숙박      I101    일반 숙박
# 1  MA010120220805432237     의성탕  NaN        S2    수리·개인      S208  욕탕·신체관리
# 2  MA010120220805432258   머릿결사랑  NaN        S2    수리·개인      S207    이용·미용
# 3  MA010120220805432850     아지트  NaN        I2       음식      I211       주점
# 4  MA010120220805436067  백석탄골부리  NaN        R1   예술·스포츠      R104   유원지·오락
#
#   상권업종소분류코드      상권업종소분류명 표준산업분류코드  ...                     건물관리번호  건물명  \
# 0    I10103            펜션   I55104  ...  4725042023105670001000001  NaN
# 1    S20801       목욕탕/사우나   S96121  ...  4773025022107490010004046  NaN
# 2    S20701           미용실   S96112  ...  4717012200102240005024992  NaN
# 3    I21104         요리 주점   I56219  ...  4713012400104380004025066  NaN
# 4    R10499  기타 오락관련 서비스업   R91299  ...  4775035040101090000000001  NaN
#
#                       도로명주소   구우편번호  신우편번호  동정보  층정보  호정보          경도  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 138545 entries, 0 to 138544
# Data columns (total 39 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   상가업소번호     138545 non-null  object
#  1   상호명        138545 non-null  object
#  2   지점명        1691 non-null    object
#  3   상권업종대분류코드  138545 non-null  object
#  4   상권업종대분류명   138545 non-null  object
#  5   상권업종중분류코드  138545 non-null  object
#  6   상권업종중분류명   138545 non-null  object
#  7   상권업종소분류코드  138545 non-null  object
#  8   상권업종소분류명   138545 non-null  object
#  9   표준산업분류코드   138487 non-null  object
#  10  표준산업분류명    138487 non-null  object
#  11  시도코드       138545 non-null  int64
#  12  시도명        138545 non-null  object
#  13  시군구코드      138545 non-null  int64
#  14  시군구명       138545 non-null  object
#  15  행정동코드      138545 non-null  int64
#  16  행정동명       138545 non-null  object
#  17  법정동코드      138545 non-null  int64
#  18  법정동명       138545 non-null  object
# ...

# %%
df.columns = df.columns.map(str)
df
# Out:
#                       상가업소번호            상호명  지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드  \
# 0       MA010120220805431708           솔밭민박  NaN        I1       숙박      I101
# 1       MA010120220805432237            의성탕  NaN        S2    수리·개인      S208
# 2       MA010120220805432258          머릿결사랑  NaN        S2    수리·개인      S207
# 3       MA010120220805432850            아지트  NaN        I2       음식      I211
# 4       MA010120220805436067         백석탄골부리  NaN        R1   예술·스포츠      R104
# ...                      ...            ...  ...       ...      ...       ...
# 138540  MA010120220809351179         현대오토바이  NaN        S2    수리·개인      S204
# 138541  MA010120220805383352  온천골가마솥국밥경북도청점  NaN        I2       음식      I201
# 138542  MA0101202302A0075828         청도친구인력  NaN        N1  시설관리·임대      N104
# 138543  MA010120220803851633       도리도리닭도리탕  NaN        I2       음식      I201
# 138544  MA010120220814179145          베스트통신  NaN        G2       소매      G208
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 138545 entries, 0 to 138544
# Data columns (total 39 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   상가업소번호     138545 non-null  object
#  1   상호명        138545 non-null  object
#  2   지점명        1691 non-null    object
#  3   상권업종대분류코드  138545 non-null  object
#  4   상권업종대분류명   138545 non-null  object
#  5   상권업종중분류코드  138545 non-null  object
#  6   상권업종중분류명   138545 non-null  object
#  7   상권업종소분류코드  138545 non-null  object
#  8   상권업종소분류명   138545 non-null  object
#  9   표준산업분류코드   138487 non-null  object
#  10  표준산업분류명    138487 non-null  object
#  11  시도코드       138545 non-null  int64
#  12  시도명        138545 non-null  object
#  13  시군구코드      138545 non-null  int64
#  14  시군구명       138545 non-null  object
#  15  행정동코드      138545 non-null  int64
#  16  행정동명       138545 non-null  object
#  17  법정동코드      138545 non-null  int64
#  18  법정동명       138545 non-null  object
# ...

# %%
df['시군구명'].values
# Out:
# array(['상주시', '의성군', '안동시', ..., '청도군', '포항시 남구', '칠곡군'], dtype=object)

# %%
#  1. 필요한 정보만 데이터 프레임으로 변경
df2 = df[['표준산업분류명', '경도', '위도', '시군구명', '상호명']]
df2
# Out:
#                        표준산업분류명          경도         위도    시군구명            상호명
# 0                          민박업  127.922707  36.543640     상주시           솔밭민박
# 1                          욕탕업  128.701183  36.352030     의성군            의성탕
# 2                       두발 미용업  128.715714  36.559903     안동시          머릿결사랑
# 3                       기타 주점업  129.212801  35.863751     경주시            아지트
# 4       그 외 기타 분류 안된 오락관련 서비스업  128.995628  36.349543     청송군         백석탄골부리
# ...                        ...         ...        ...     ...            ...
# 138540               모터사이클 수리업  128.089427  36.358164     상주시         현대오토바이
# 138541              한식 일반 음식점업  128.500179  36.576034     안동시  온천골가마솥국밥경북도청점
# 138542                  고용 알선업  128.888500  35.694607     청도군         청도친구인력
# 138543              한식 일반 음식점업  129.358611  36.015412  포항시 남구       도리도리닭도리탕
# 138544                통신기기 소매업  128.347027  36.069870     칠곡군          베스트통신
#
# [138545 rows x 5 columns]

# %%
df3 = df2[(df2['시군구명'] == '경산시') & (df2['표준산업분류명'] == '커피 전문점')]
df3.head()
df3.tail()
# Out:
#        표준산업분류명          경도         위도 시군구명         상호명
# 136391  커피 전문점  128.764731  35.838254  경산시        짹슨커피
# 136967  커피 전문점  128.823483  35.822976  경산시  베러먼데이경산자인점
# 137003  커피 전문점  128.719311  35.828016  경산시  베러먼데이펜타힐즈점
# 137242  커피 전문점  128.739408  35.796790  경산시          꼬깜
# 138275  커피 전문점  128.758032  35.806534  경산시        르솔커피

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 604 entries, 435 to 138275
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   표준산업분류명  604 non-null    object
#  1   경도       604 non-null    float64
#  2   위도       604 non-null    float64
#  3   시군구명     604 non-null    object
#  4   상호명      604 non-null    object
# dtypes: float64(2), object(3)
# memory usage: 28.3+ KB

# %%
df3
# Out:
#        표준산업분류명          경도         위도 시군구명         상호명
# 435     커피 전문점  128.817535  35.875275  경산시    아틀리에빈진량점
# 510     커피 전문점  128.737730  35.825841  경산시    더벤티경산중방점
# 538     커피 전문점  128.761142  35.812436  경산시       너와나커피
# 565     커피 전문점  128.729624  35.818094  경산시       눈꽃이피다
# 931     커피 전문점  128.816056  35.912464  경산시         해르트
# ...        ...         ...        ...  ...         ...
# 136391  커피 전문점  128.764731  35.838254  경산시        짹슨커피
# 136967  커피 전문점  128.823483  35.822976  경산시  베러먼데이경산자인점
# 137003  커피 전문점  128.719311  35.828016  경산시  베러먼데이펜타힐즈점
# 137242  커피 전문점  128.739408  35.796790  경산시          꼬깜
# 138275  커피 전문점  128.758032  35.806534  경산시        르솔커피
#
# [604 rows x 5 columns]

# %%
import folium.map

# 경산 지도 객체 생성
gyeongsan_map = folium.Map(location=[35.9542891, 128.833745], zoom_star=13, tiles='Cartodb Positron')
gyeongsan_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
# popup : 마우스 클릭시 나옴 : tooltip : 마우스 호버 시 나옴
for name, lat, lng in zip(df3['상호명'], df3['위도'], df3['경도']):
    tooltip = folium.Tooltip(name, permanent=True)
    folium.Marker(location=[lat, lng], tooltip=tooltip).add_to(gyeongsan_map)
gyeongsan_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 604 entries, 435 to 138275
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   표준산업분류명  604 non-null    object
#  1   경도       604 non-null    float64
#  2   위도       604 non-null    float64
#  3   시군구명     604 non-null    object
#  4   상호명      604 non-null    object
# dtypes: float64(2), object(3)
# memory usage: 28.3+ KB

# %%
gyeongsan_map.save('./output/gyeongsan_map.html')
